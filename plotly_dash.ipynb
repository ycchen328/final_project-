# %%
# !pip install dash==1.19.0  

# !pip install jupyter_dash 

# !pip install --upgrade plotly

import pandas as pd
import dash
import dash_html_components as html
import dash_core_components as dcc
from dash.dependencies import Input, Output
from jupyter_dash import JupyterDash
import plotly.graph_objects as go
import plotly.express as px
# Out:
# Requirement already satisfied: dash==1.19.0 in c:\users\65935\anaconda3\lib\site-packages (1.19.0)
# Requirement already satisfied: plotly in c:\users\65935\anaconda3\lib\site-packages (from dash==1.19.0) (5.11.0)
# Requirement already satisfied: dash-html-components==1.1.2 in c:\users\65935\anaconda3\lib\site-packages (from dash==1.19.0) (1.1.2)
# Requirement already satisfied: flask-compress in c:\users\65935\anaconda3\lib\site-packages (from dash==1.19.0) (1.13)
# Requirement already satisfied: dash-renderer==1.9.0 in c:\users\65935\anaconda3\lib\site-packages (from dash==1.19.0) (1.9.0)
# Requirement already satisfied: dash-table==4.11.2 in c:\users\65935\anaconda3\lib\site-packages (from dash==1.19.0) (4.11.2)
# Requirement already satisfied: Flask>=1.0.4 in c:\users\65935\anaconda3\lib\site-packages (from dash==1.19.0) (1.1.2)
# Requirement already satisfied: future in c:\users\65935\anaconda3\lib\site-packages (from dash==1.19.0) (0.18.2)
# Requirement already satisfied: dash-core-components==1.15.0 in c:\users\65935\anaconda3\lib\site-packages (from dash==1.19.0) (1.15.0)
# Requirement already satisfied: itsdangerous>=0.24 in c:\users\65935\anaconda3\lib\site-packages (from Flask>=1.0.4->dash==1.19.0) (2.0.1)
# Requirement already satisfied: click>=5.1 in c:\users\65935\anaconda3\lib\site-packages (from Flask>=1.0.4->dash==1.19.0) (8.0.3)
# Requirement already satisfied: Jinja2>=2.10.1 in c:\users\65935\anaconda3\lib\site-packages (from Flask>=1.0.4->dash==1.19.0) (2.11.3)
# Requirement already satisfied: Werkzeug>=0.15 in c:\users\65935\anaconda3\lib\site-packages (from Flask>=1.0.4->dash==1.19.0) (2.0.2)
# Requirement already satisfied: colorama in c:\users\65935\anaconda3\lib\site-packages (from click>=5.1->Flask>=1.0.4->dash==1.19.0) (0.4.4)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\65935\anaconda3\lib\site-packages (from Jinja2>=2.10.1->Flask>=1.0.4->dash==1.19.0) (1.1.1)
# Requirement already satisfied: brotli in c:\users\65935\anaconda3\lib\site-packages (from flask-compress->dash==1.19.0) (1.0.9)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\65935\anaconda3\lib\site-packages (from plotly->dash==1.19.0) (8.1.0)
# Requirement already satisfied: jupyter_dash in c:\users\65935\anaconda3\lib\site-packages (0.4.2)
# Requirement already satisfied: dash in c:\users\65935\anaconda3\lib\site-packages (from jupyter_dash) (1.19.0)
# Requirement already satisfied: ansi2html in c:\users\65935\anaconda3\lib\site-packages (from jupyter_dash) (1.8.0)
# Requirement already satisfied: retrying in c:\users\65935\anaconda3\lib\site-packages (from jupyter_dash) (1.3.3)
# Requirement already satisfied: requests in c:\users\65935\anaconda3\lib\site-packages (from jupyter_dash) (2.26.0)
# Requirement already satisfied: ipython in c:\users\65935\anaconda3\lib\site-packages (from jupyter_dash) (7.29.0)
# Requirement already satisfied: nest-asyncio in c:\users\65935\anaconda3\lib\site-packages (from jupyter_dash) (1.5.1)
# Requirement already satisfied: flask in c:\users\65935\anaconda3\lib\site-packages (from jupyter_dash) (1.1.2)
# Requirement already satisfied: ipykernel in c:\users\65935\anaconda3\lib\site-packages (from jupyter_dash) (6.4.1)
# Requirement already satisfied: dash-html-components==1.1.2 in c:\users\65935\anaconda3\lib\site-packages (from dash->jupyter_dash) (1.1.2)
# Requirement already satisfied: plotly in c:\users\65935\anaconda3\lib\site-packages (from dash->jupyter_dash) (5.11.0)
# Requirement already satisfied: future in c:\users\65935\anaconda3\lib\site-packages (from dash->jupyter_dash) (0.18.2)
# Requirement already satisfied: dash-renderer==1.9.0 in c:\users\65935\anaconda3\lib\site-packages (from dash->jupyter_dash) (1.9.0)
# Requirement already satisfied: dash-core-components==1.15.0 in c:\users\65935\anaconda3\lib\site-packages (from dash->jupyter_dash) (1.15.0)
# Requirement already satisfied: flask-compress in c:\users\65935\anaconda3\lib\site-packages (from dash->jupyter_dash) (1.13)
# Requirement already satisfied: dash-table==4.11.2 in c:\users\65935\anaconda3\lib\site-packages (from dash->jupyter_dash) (4.11.2)
# Requirement already satisfied: Jinja2>=2.10.1 in c:\users\65935\anaconda3\lib\site-packages (from flask->jupyter_dash) (2.11.3)
# Requirement already satisfied: click>=5.1 in c:\users\65935\anaconda3\lib\site-packages (from flask->jupyter_dash) (8.0.3)
# Requirement already satisfied: Werkzeug>=0.15 in c:\users\65935\anaconda3\lib\site-packages (from flask->jupyter_dash) (2.0.2)
# Requirement already satisfied: itsdangerous>=0.24 in c:\users\65935\anaconda3\lib\site-packages (from flask->jupyter_dash) (2.0.1)
# Requirement already satisfied: colorama in c:\users\65935\anaconda3\lib\site-packages (from click>=5.1->flask->jupyter_dash) (0.4.4)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\65935\anaconda3\lib\site-packages (from Jinja2>=2.10.1->flask->jupyter_dash) (1.1.1)
# Requirement already satisfied: brotli in c:\users\65935\anaconda3\lib\site-packages (from flask-compress->dash->jupyter_dash) (1.0.9)
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in c:\users\65935\anaconda3\lib\site-packages (from ipykernel->jupyter_dash) (1.4.1)
# Requirement already satisfied: ipython-genutils in c:\users\65935\anaconda3\lib\site-packages (from ipykernel->jupyter_dash) (0.2.0)
# Requirement already satisfied: tornado<7.0,>=4.2 in c:\users\65935\anaconda3\lib\site-packages (from ipykernel->jupyter_dash) (6.1)
# Requirement already satisfied: jupyter-client<8.0 in c:\users\65935\anaconda3\lib\site-packages (from ipykernel->jupyter_dash) (6.1.12)
# Requirement already satisfied: traitlets<6.0,>=4.1.0 in c:\users\65935\anaconda3\lib\site-packages (from ipykernel->jupyter_dash) (5.1.0)
# Requirement already satisfied: matplotlib-inline<0.2.0,>=0.1.0 in c:\users\65935\anaconda3\lib\site-packages (from ipykernel->jupyter_dash) (0.1.2)
# Requirement already satisfied: decorator in c:\users\65935\anaconda3\lib\site-packages (from ipython->jupyter_dash) (5.1.0)
# Requirement already satisfied: jedi>=0.16 in c:\users\65935\anaconda3\lib\site-packages (from ipython->jupyter_dash) (0.18.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\65935\anaconda3\lib\site-packages (from ipython->jupyter_dash) (3.0.20)
# Requirement already satisfied: pickleshare in c:\users\65935\anaconda3\lib\site-packages (from ipython->jupyter_dash) (0.7.5)
# Requirement already satisfied: backcall in c:\users\65935\anaconda3\lib\site-packages (from ipython->jupyter_dash) (0.2.0)
# Requirement already satisfied: setuptools>=18.5 in c:\users\65935\anaconda3\lib\site-packages (from ipython->jupyter_dash) (58.0.4)
# Requirement already satisfied: pygments in c:\users\65935\anaconda3\lib\site-packages (from ipython->jupyter_dash) (2.10.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\65935\anaconda3\lib\site-packages (from jedi>=0.16->ipython->jupyter_dash) (0.8.2)
# Requirement already satisfied: pyzmq>=13 in c:\users\65935\anaconda3\lib\site-packages (from jupyter-client<8.0->ipykernel->jupyter_dash) (22.2.1)
# Requirement already satisfied: jupyter-core>=4.6.0 in c:\users\65935\anaconda3\lib\site-packages (from jupyter-client<8.0->ipykernel->jupyter_dash) (4.8.1)
# Requirement already satisfied: python-dateutil>=2.1 in c:\users\65935\anaconda3\lib\site-packages (from jupyter-client<8.0->ipykernel->jupyter_dash) (2.8.2)
# Requirement already satisfied: pywin32>=1.0 in c:\users\65935\anaconda3\lib\site-packages (from jupyter-core>=4.6.0->jupyter-client<8.0->ipykernel->jupyter_dash) (228)
# Requirement already satisfied: wcwidth in c:\users\65935\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->jupyter_dash) (0.2.5)
# Requirement already satisfied: six>=1.5 in c:\users\65935\anaconda3\lib\site-packages (from python-dateutil>=2.1->jupyter-client<8.0->ipykernel->jupyter_dash) (1.16.0)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\65935\anaconda3\lib\site-packages (from plotly->dash->jupyter_dash) (8.1.0)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\65935\anaconda3\lib\site-packages (from requests->jupyter_dash) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\65935\anaconda3\lib\site-packages (from requests->jupyter_dash) (1.26.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\65935\anaconda3\lib\site-packages (from requests->jupyter_dash) (2022.9.24)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\65935\anaconda3\lib\site-packages (from requests->jupyter_dash) (3.2)
# Requirement already satisfied: plotly in c:\users\65935\anaconda3\lib\site-packages (5.11.0)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\65935\anaconda3\lib\site-packages (from plotly) (8.1.0)

# %%
app = JupyterDash(__name__)

# %%
spacex_df = pd.read_csv("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/datasets/spacex_launch_dash.csv")

# %%
max_payload = spacex_df['Payload Mass (kg)'].max()
min_payload = spacex_df['Payload Mass (kg)'].min()

# %%
unique_launch_sites = spacex_df['Launch Site'].unique().tolist()
launch_sites = []
launch_sites.append({'label': 'All Sites', 'value': 'All Sites'})
for launch_site in unique_launch_sites:
    launch_sites.append({'label': launch_site, 'value': launch_site})

# %%
marks_dict = {}
for i in range(0,11000,1000):
    marks_dict[i] = {'label': str(i)+' Kg'}

# %%
# Create an app layout
app.layout = html.Div(children=[html.H1('SpaceX Launch Records Dashboard',
                                        style={'textAlign': 'center', 'color': '#503D36',
                                               'font-size': 40}),
                                # TASK 1: Add a dropdown list to enable Launch Site selection
                                # The default select value is for ALL sites
                                # dcc.Dropdown(id='site-dropdown',...)
                                dcc.Dropdown(
                                    id = 'site-dropdown',
                                    options=[
                                            {'label': 'All Sites', 'value': 'ALL'},
                                            {'label': 'CCAFS LC-40', 'value': 'CCAFS LC-40'},
                                            {'label': 'VAFB SLC-4E', 'value': 'VAFB SLC-4E'},
                                            {'label': 'KSC LC-39A', 'value': 'KSC LC-39A'},
                                            {'label': 'CCAFS SLC-40', 'value': 'CCAFS SLC-40'}
                                            ],
                                    placeholder = 'Select a Launch Site',
                                    searchable = True ,
                                    value = 'All Sites'
                                ),
                                html.Br(),

                                # TASK 2: Add a pie chart to show the total successful launches count for all sites
                                # If a specific launch site was selected, show the Success vs. Failed counts for the site
                                html.Div(dcc.Graph(id='success-pie-chart')),
                                html.Br(),

                                html.P("Payload range (Kg):"),
                                # TASK 3: Add a slider to select payload range
                                #dcc.RangeSlider(id='payload-slider',...)
                                html.Div([
                                    dcc.RangeSlider(
                                        id = 'payload_slider',
                                        min = 0,
                                        max = 10000,
                                        step = 1000,
                                        marks = marks_dict,
                                        value = [min_payload, max_payload]
                                    ),
                                ], style={'padding':'40px 30px'}),
                                
                                # TASK 4: Add a scatter chart to show the correlation between payload and launch success
                                html.Div(dcc.Graph(id='success-payload-scatter-chart')),
                                ])

# TASK 5:
# Add a callback function for `site-dropdown` as input, `success-pie-chart` as output
@app.callback(
     Output(component_id = 'success-pie-chart', component_property = 'figure'),
     [Input(component_id = 'site-dropdown', component_property = 'value')]
)
def pie_chart(site_dropdown):
    if site_dropdown == 'All Sites' or site_dropdown == 'None':
        data  = spacex_df[spacex_df['class'] == 1]
        fig = px.pie(
                data,
                names = 'Launch Site',
                title = 'Total Success Launches by Site'
            )
    else:
        data = spacex_df.loc[spacex_df['Launch Site'] == site_dropdown]
        fig = px.pie(
                data,
                names = 'class',
                title = 'Total Success Launches for Site ' + site_dropdown,
            )
    return fig

# TASK 6:
# Add a callback function for `site-dropdown` and `payload-slider` as inputs, `success-payload-scatter-chart` as output
@app.callback(Output(component_id = 'success-payload-scatter-chart', component_property = 'figure'),
     [Input(component_id = 'site-dropdown', component_property = 'value'), 
     Input(component_id = "payload_slider", component_property = "value")])
def update_scatterplot(site_dropdown, payload_slider):
    low, high = payload_slider
    if (site_dropdown == 'All Sites' or site_dropdown == 'None'):
        print(payload_slider)
        low, high = payload_slider
        data = spacex_df[spacex_df['Payload Mass (kg)'].between(low, high)]
        fig = px.scatter(
                data, 
                x = "Payload Mass (kg)", 
                y = "class",
                title = 'Correlation between Payload and Success for all Sites',
                color = "Booster Version Category"
            )
    else:
        print(payload_slider)
        low, high = payload_slider
        data = spacex_df[spacex_df['Payload Mass (kg)'].between(low, high)]
        data_filtered = data[data['Launch Site'] == site_dropdown]
        fig = px.scatter(
                data_filtered,
                x = "Payload Mass (kg)",
                y = "class",
                title = 'Correlation between Payload and Success for site '+ site_dropdown,
                color = "Booster Version Category"
            )
    return fig

# Run the app
if __name__ == '__main__':
    app.run_server()
# Out:
# Dash app running on http://127.0.0.1:8050/
# [0, 9600]
